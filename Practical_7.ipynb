# %% [markdown]
# # Practical_7: Matplotlib

# %% [markdown]
# ---
#
# ### Exercise 1:
# Create a simple line plot for `y = x` for `x` values ranging from 0 to 10.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Exercise 1
x = np.arange(0,10)
y = x 
plt.plot(x,y,color = 'g')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 2:
# Plot `y = x^2` using Matplotlib for `x` values between -10 and 10.

# %%
# Exercise 2
x = np.arange(-10,10)
y = x**2
plt.plot(x,y,color='g')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r"Plot of $y=x^2$")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 3:
# Create a scatter plot with 50 random points where x and y values are between 0 and 10.

# %%
# Exercise 3
x= np.random.uniform(0,10,50)
y = np.random.uniform(0,10,50)
plt.scatter(x,y,color='g')
plt.xlabel('x')
plt.ylabel('y')
plt.title("A scatter plot of 50 random values")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 4:
# Plot a sine wave using Matplotlib for `x` values between 0 and 2π.

# %%
# Exercise 4
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Plot the sine wave
plt.plot(x, y, label='sin(x)', color='green')
plt.title('Sine Wave')
plt.xlabel('x (radians)')
plt.ylabel('sin(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 5:
# Create a bar chart for the following data: `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
# Exercise 5
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
plt.bar(categories,values, color = "g")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Different categories and values")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 6:
# Create a histogram of 1000 random numbers generated from a normal distribution.

# %%
# Exercise 6
# Generate 1000 random numbers from a normal distribution (mean=0, std=1)
data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=15, color='g', edgecolor='black')
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
# plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 7:
# Plot two line plots on the same graph: `y1 = x^2` and `y2 = x^3` for `x` ranging from 0 to 10.

# %%
# Exercise 7
x = np.random.rand(0,10)
x = np.linspace(0, 10)
y1 = x**2
y2 = x**3
plt.plot(x, y1, label='y = x²', color='g')
plt.plot(x, y2, label='y = x³', color='b')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 8:
# Add titles, axis labels, and a legend to the plot in Exercise 7.

# %%
# Exercise 8
x = np.random.rand(0,10)
x = np.linspace(0, 10)
y1 = x**2
y2 = x**3
plt.plot(x, y1, label='y = x²', color='b')
plt.plot(x, y2, label='y = x³', color='g')
plt.title('Comparison of y = x² and y = x³', fontsize=14)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 9:
# Create a subplot with 2 rows and 1 column. Plot `y1 = x^2` in the first subplot and `y2 = x^3` in the second.

# %%
# Exercise 9
x = np.linspace(0, 10, 100)
y1 = x ** 2  
y2 = x ** 3  

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(5, 8))

# First subplot: y = x²
ax1.plot(x, y1, color='g', label='y = x²')
ax1.set_title('Quadratic Function (y = x²)')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.grid(True)
ax1.legend()

# Second subplot: y = x³
ax2.plot(x, y2, color='blue', label='y = x³', linewidth=2)
ax2.set_title('Cubic Function (y = x³)', fontsize=12)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.grid(True)
ax2.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 10:
# Use a different color and linestyle for each line in a plot of three functions: `y1 = x`, `y2 = x^2`, and `y3 = x^3`.

# %%
# Exercise 10
x = np.linspace(0, 10, 100)
y1 = x       
y2 = x ** 2  
y3 = x ** 3  

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='y = x', color='green', linestyle='-')      
plt.plot(x, y2, label='y = x²', color='blue', linestyle='--')   
plt.plot(x, y3, label='y = x³', color='red', linestyle=':')    

plt.title('Comparison of y = x, y = x², and y = x³')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 11:
# Create a pie chart with 5 segments labeled A, B, C, D, and E, with values `[25, 35, 20, 15, 5]`.

# %%
# Exercise 11
labels = ['A', 'B', 'C', 'D', 'E']
sizes = [25, 35, 20, 15, 5]
colors = ['gold', 'green', 'blue', 'pink', 'violet']  
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Pie Chart with 5 Segments (A-E)')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 12:
# Create a horizontal bar chart with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
# Exercise 12
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
plt.barh(categories,values,color='g')
plt.title('Categories with their values')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 13:
# Change the figure size of a line plot to 10x6 inches.

# %%
# Exercise 13
x = np.linspace(0, 10, 100)
y = x ** 2  
plt.figure(figsize=(10, 6)) 
plt.plot(x, y, color='g', label='y = x²')
plt.title('Line Plot (Figure Size: 10x6 inches)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 14:
# Plot a filled area under the curve of `y = x^2` for `x` ranging from 0 to 10.

# %%
# Exercise 14
x = np.linspace(0, 10, 100)
y = x**2

plt.plot(x, y, label='y = x^2', color='g')
plt.fill_between(x, y, color='lightgreen')
plt.title('Filled Area Under y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 15:
# Change the style of the plot to `ggplot` and replot the sine wave from Exercise 4.

# %%
# Exercise 15
  
plt.style.use('ggplot')
x = np.linspace(0, 2 * np.pi, 100)  # 0 to 2π (full sine cycle)
y = np.sin(x)

plt.plot(x, y, 
         color='g',  
         linewidth=2, 
         label='y = sin(x)',
         markersize=4)

plt.title('Sine Wave (ggplot Style)')
plt.xlabel('x (radians)')
plt.ylabel('sin(x)')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 16:
# Create a stacked bar chart for the following data: `Group A = [3, 5, 7]`, `Group B = [2, 6, 4]`, and `categories = ['X', 'Y', 'Z']`.

# %%
# Exercise 16
categories = ['X', 'Y', 'Z']
group_a = [3, 5, 7]
group_b = [2, 6, 4]

plt.bar(categories, group_a, label='Group A', color='g')
plt.bar(categories, group_b, bottom=group_a, label='Group B', color='lightgreen')
plt.title('Stacked Bar Chart: Group A vs Group B')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 17:
# Create a plot with multiple subplots in a 2x2 grid. Plot `y1 = x`, `y2 = x^2`, `y3 = x^3`, and `y4 = x^4`.

# %%
# Exercise 17
x = np.linspace(0, 5, 100)  # x from 0 to 5
y1 = x       # Linear
y2 = x**2    # Quadratic
y3 = x**3    # Cubic
y4 = x**4    # Quartic

fig, axs = plt.subplots(2, 2, figsize=(10, 8))
fig.suptitle('Polynomial Functions Subplots', fontsize=16)

# Plot 1
axs[0, 0].plot(x, y1, color='blue')
axs[0, 0].set_title('y = x')
axs[0, 0].grid(True, linestyle='--', alpha=0.6)

# Plot 2
axs[0, 1].plot(x, y2, color='green')
axs[0, 1].set_title('y = x²')
axs[0, 1].grid(True)

# Plot 3
axs[1, 0].plot(x, y3, color='red')
axs[1, 0].set_title('y = x³')
axs[1, 0].grid(True)

# Plot 4
axs[1, 1].plot(x, y4, color='purple')
axs[1, 1].set_title('y = x⁴')
axs[1, 1].grid(True)

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 18:
# Create a heatmap using a 2D array of random values with shape (5, 5).

# %%
# Exercise 18
data = np.random.rand(5, 5)
plt.figure(figsize=(6, 6))
heatmap = plt.imshow(data, cmap='viridis')

plt.colorbar(heatmap, label='Value')
plt.xticks(np.arange(5), labels=[f'X{i+1}' for i in range(5)])
plt.yticks(np.arange(5), labels=[f'Y{i+1}' for i in range(5)])

# Add value annotations
for i in range(5):
    for j in range(5):
        plt.text(j, i, f'{data[i, j]:.2f}', 
                 ha='center', va='center', 
                 color='white' if data[i, j] > 0.5 else 'black')

plt.title('5×5 Heatmap of Random Values', pad=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 19:
# Add error bars to a bar plot with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`, assuming the error is 1 for each value.

# %%
# Exercise 19
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
errors = [1, 1, 1, 1]

plt.bar(categories, values, yerr=errors, capsize=5, color='g', edgecolor='black')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot with Error Bars')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 20:
# Plot a sine wave using a dashed line and a cosine wave using a solid line on the same plot.

# %%
# Exercise 20
x = np.linspace(0, 2 * np.pi, 100)
sine_y = np.sin(x)
cosine_y = np.cos(x)

plt.plot(x, sine_y, '--', label='Sine', color='blue')
plt.plot(x, cosine_y, '-', label='Cosine', color='g')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine and Cosine Waves')
plt.legend()

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 21:
# Plot a contour plot for the function `z = sin(x) + cos(y)` over a grid of `x` and `y` values ranging from -5 to 5.

# %%
# Exercise 21
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)

plt.contourf(X, Y, Z, cmap='viridis')
plt.colorbar()
plt.title('Contour plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 22:
# Create a box plot for a dataset generated with 100 random numbers from a normal distribution.

# %%
# Exercise 22
data = np.random.normal(size=100)
plt.boxplot(data)
plt.title('Box plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 23:
# Create a scatter plot with a color map applied to the points, where the color represents the value of the points.

# %%
# Exercise 23
x = np.random.rand(100)
y = np.random.rand(100)
colors = x + y
plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.title('Scatter plot with colormap')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 24:
# Use Matplotlib to display an image from a file.

# %%
import matplotlib.image as mpimg
img = mpimg.imread(r"C:\Users\User\Downloads\balconies.png" )
plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 25:
# Create a plot with logarithmic scaling on both axes.

# %%
# Exercise 25
x = np.logspace(0.1, 2, 100)
y = x**2
plt.loglog(x, y)
plt.title('Log-log plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 26:
# Create a 3D plot of the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
# Exercise 26
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
plt.title('3D plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 27:
# Create a radar chart with 5 variables and random values between 0 and 1.

# %%
# Exercise 27
labels = ['A', 'B', 'C', 'D', 'E']
stats = np.random.rand(5)
stats = np.concatenate((stats, [stats[0]]))
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

fig, ax = plt.subplots(subplot_kw={'polar': True})
ax.plot(angles, stats)
ax.fill(angles, stats, alpha=0.25)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title('Radar chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 28:
# Create a violin plot to show the distribution of a dataset generated with 1000 random numbers from a normal distribution.

# %%
# Exercise 28
data = np.random.normal(size=1000)
plt.violinplot(data)
plt.title('Violin plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 29:
# Create a bar chart with different colors for each bar.

# %%
# Exercise 29
values = np.random.randint(1, 10, 5)
colors = ['red', 'green', 'blue', 'orange', 'purple']
plt.bar(range(len(values)), values, color=colors)
plt.title('Colored bar chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 30:
# Create a stem plot for the function `y = sin(x)` for `x` values between 0 and 2π.

# %%
# Exercise 30
x = np.linspace(0, 2*np.pi, 50)
y = np.sin(x)
plt.stem(x, y)
plt.title('Stem plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 31:
# Create a scatter plot with markers of different sizes.

# %%
# Exercise 31
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
plt.scatter(x, y, s=sizes, alpha=0.5, color = "g")
plt.title('Scatter with sizes')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 32:
# Plot a cumulative histogram of 1000 random numbers generated from a uniform distribution.

# %%
# Exercise 32
data = np.random.rand(1000)
plt.hist(data, bins=30, cumulative=True, color = 'g')
plt.title('Cumulative histogram')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 33:
# Create a pie chart with custom colors for each segment.

# %%
# Exercise 33
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['gold', 'blue', 'green', 'yellowgreen']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Pie chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 34:
# Create a plot with twin y-axes where one axis represents `y = x` and the other represents `y = x^2`.

# %%
# Exercise 34
x = np.linspace(0, 10, 100)
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(x, x, 'g-', label='y = x')
ax2.plot(x, x**2, 'b-', label='y = x^2')
ax1.set_xlabel('x')
ax1.set_ylabel('y = x', color='g')
ax2.set_ylabel('y = x^2', color='b')
plt.title('Twin y-axes')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 35:
# Plot a density plot of 1000 random values from a normal distribution.

# %%
# Exercise 35
data = np.random.normal(size=1000)
plt.hist(data, bins=15, density=True, alpha=0.6, color='g')
plt.title('Density plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 36:
# Create a histogram and add a kernel density estimate (KDE) to the plot.

# %%
# Exercise 36
from scipy.stats import gaussian_kde
data = np.random.normal(size=1000)

kde = gaussian_kde(data)
x_vals = np.linspace(min(data), max(data), 1000)
kde_vals = kde(x_vals)

plt.hist(data, bins=30, density=True, alpha=0.5, label='Histogram', color='g')
plt.plot(x_vals, kde_vals, color='red', label='KDE')
plt.title('Histogram with KDE')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 37:
# Add gridlines to a line plot and change the color and linestyle of the grid.

# %%
# Exercise 37
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, color='g')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.title('Line plot with gridlines')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 38:
# Create a bar chart with annotations showing the height of each bar above the bar.

# %%
# Exercise 38
values = np.random.randint(1, 10, 5)
bars = plt.bar(range(len(values)), values, color = 'g')
for i, bar in enumerate(bars):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.1,
             f'{bar.get_height()}', ha='center')
plt.title('Bar chart with annotations')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 39:
# Create a filled contour plot for the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
# Exercise 39
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2
plt.contourf(X, Y, Z, cmap='viridis')
plt.colorbar()
plt.title('Filled contour plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 40:
# Create a stacked area plot using three random datasets.

# %%
# Exercise 40
x = np.arange(100)
y1 = np.random.rand(100)
y2 = np.random.rand(100)
y3 = np.random.rand(100)
plt.stackplot(x, y1, y2, y3, labels=['A', 'B', 'C'])
plt.legend()
plt.title('Stacked area plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 41:
# Create a bar chart with error bars, where the error values are proportional to the bar values.

# %%
# Exercise 41
values = np.random.rand(5) * 10
errors = values * 0.1
plt.bar(range(len(values)), values, yerr=errors, capsize=5, color = 'g')
plt.title('Bar chart with error bars')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 42:
# Create a wind rose chart using random wind direction and speed data.

# %%
# Exercise 42
import matplotlib.cm as cm
import matplotlib.colors as mcolors

angles = np.random.uniform(0, 360, 100)
speeds = np.random.rand(100) * 10

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
angles_rad = np.deg2rad(angles)
bars = ax.bar(angles_rad, speeds, width=0.2, bottom=0.0, color=cm.viridis(speeds / speeds.max()))
plt.title('Wind rose chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 43:
# Plot a cumulative frequency curve for a dataset of 100 random numbers.

# %%
# Exercise 43
data = np.random.randn(100)
data_sorted = np.sort(data)
cum_freq = np.arange(1, len(data_sorted)+1) / len(data_sorted)
plt.plot(data_sorted, cum_freq, color = 'g')
plt.title('Cumulative frequency curve')
plt.xlabel('Value')
plt.ylabel('Cumulative Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 44:
# Create a waterfall chart using Matplotlib to show the changes in a sequence of values.

# %%
# Exercise 44
values = [100, -20, 30, -10, 50]
indexes = np.arange(len(values))
cum_values = np.cumsum([0] + values[:-1])
plt.bar(indexes, values, bottom=cum_values)
plt.title('Waterfall chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 45:
# Use the `imshow` function to display a 10x10 matrix of random values as an image.

# %%
# Exercise 45
matrix = np.random.rand(10, 10)
plt.imshow(matrix, cmap='viridis')
plt.colorbar()
plt.title('imshow of 10x10 matrix')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 46:
# Create a line plot with different markers for each point.

# %%
# Exercise 46
x = np.arange(10)
y = np.random.rand(10)
markers = ['o', 'v', '^', '<', '>', 's', 'p', '*', '+', 'x']
for i in range(len(x)):
    plt.plot(x[i], y[i], marker=markers[i])
plt.plot(x,y,linestyle = '-', color = 'g')
plt.title('Line plot with different markers')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 47:
# Create a time series plot using Matplotlib and plot random data over a range of dates.

# %%
# Exercise 47
import pandas as pd

dates = pd.date_range(start='2023-01-01', periods=100)
data = np.random.randn(100).cumsum()
plt.plot(dates, data, color = 'g')
plt.title('Time series plot')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 48:
# Create a bar chart with bars colored by category.

# %%
# Exercise 48
categories = ['A', 'B', 'C', 'D']
values = np.random.randint(5, 15, size=4)
colors = ['blue', 'red', 'limegreen', 'violet']
plt.bar(categories, values, color=colors)
plt.title('Bar chart by category')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 49:
# Create a radar chart to visualize the strengths of five different attributes.

# %%
# Exercise 49
attributes = ['Speed', 'Strength', 'Skill', 'Agility', 'Endurance']
values = np.random.rand(5)
values = np.concatenate((values, [values[0]]))
angles = np.linspace(0, 2*np.pi, len(attributes), endpoint=False).tolist()
angles += angles[:1]

fig, ax = plt.subplots(subplot_kw={'polar': True})
ax.plot(angles, values)
ax.fill(angles, values, alpha=0.25)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(attributes)
plt.title('Radar chart for attributes')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 50:
# Create a 3D scatter plot with random values for x, y, and z.

# %%
# Exercise 50
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)
ax.scatter(x, y, z, c=z, cmap='plasma')
plt.title('3D scatter plot')
plt.show()

# %% [markdown]
# ---
